# %% [markdown]
# ## NYC_Taxy_data_analysis
#
# #### Queries
# 1. Add a column named as "Revenue" into dataframe which is the sum of the columns 'Fare_amount','Extra','MTA_tax','Improvement_surcharge','Tip_amount','Tolls_amount','Total_amount'
# 2.  Increasing count of total passengers in New York City by area
# 3.  Realtime Average fare/total earning amount earned by 2 vendors
# 4. Moving Count of payments made by each payment mode
# 5.  Highest two gaining vendor's on a particular date with no of passenger and total distance by cab
# 6.  Most no of passenger between a route of two location.
# 7. Get top pickup locations with most passengers in last 5/10 seconds.

# %%
# File location and type
file_location = "/FileStore/tables/yellow_tripdata_2018_01__1_.parquet"
file_type = "parquet"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>tpep_pickup_datetime</th><th>tpep_dropoff_datetime</th><th>passenger_count</th><th>trip_distance</th><th>RatecodeID</th><th>store_and_fwd_flag</th><th>PULocationID</th><th>DOLocationID</th><th>payment_type</th><th>fare_amount</th><th>extra</th><th>mta_tax</th><th>tip_amount</th><th>tolls_amount</th><th>improvement_surcharge</th><th>total_amount</th><th>congestion_surcharge</th><th>airport_fee</th></tr></thead><tbody><tr><td>1</td><td>2018-01-01T00:21:05.000+0000</td><td>2018-01-01T00:24:23.000+0000</td><td>1</td><td>0.5</td><td>1</td><td>N</td><td>41</td><td>24</td><td>2</td><td>4.5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>5.8</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2018-01-01T00:44:55.000+0000</td><td>2018-01-01T01:03:05.000+0000</td><td>1</td><td>2.7</td><td>1</td><td>N</td><td>239</td><td>140</td><td>2</td><td>14.0</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>15.3</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2018-01-01T00:08:26.000+0000</td><td>2018-01-01T00:14:21.000+0000</td><td>2</td><td>0.8</td><td>1</td><td>N</td><td>262</td><td>141</td><td>1</td><td>6.0</td><td>0.5</td><td>0.5</td><td>1.0</td><td>0.0</td><td>0.3</td><td>8.3</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2018-01-01T00:20:22.000+0000</td><td>2018-01-01T00:52:51.000+0000</td><td>1</td><td>10.2</td><td>1</td><td>N</td><td>140</td><td>257</td><td>2</td><td>33.5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>34.8</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2018-01-01T00:09:18.000+0000</td><td>2018-01-01T00:27:06.000+0000</td><td>2</td><td>2.5</td><td>1</td><td>N</td><td>246</td><td>239</td><td>1</td><td>12.5</td><td>0.5</td><td>0.5</td><td>2.75</td><td>0.0</td><td>0.3</td><td>16.55</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
df.printSchema()
# Out:
# root
#  |-- VendorID: long (nullable = true)
#  |-- tpep_pickup_datetime: timestamp (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: long (nullable = true)
#  |-- DOLocationID: long (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- airport_fee: double (nullable = true)

# %% [markdown]
# ##### 1. Add a column named as "Revenue" into dataframe which is the sum of the columns 'Fare_amount','Extra','MTA_tax','Improvement_surcharge','Tip_amount','Tolls_amount','Total_amount'

# %%
from pyspark.sql.functions import *
df=df.withColumn("Revenue",col('Fare_amount')+col('Extra')+col('MTA_tax')+col('Improvement_surcharge')+col('Tip_amount')+col('Tolls_amount')+col('Total_amount'))
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>tpep_pickup_datetime</th><th>tpep_dropoff_datetime</th><th>passenger_count</th><th>trip_distance</th><th>RatecodeID</th><th>store_and_fwd_flag</th><th>PULocationID</th><th>DOLocationID</th><th>payment_type</th><th>fare_amount</th><th>extra</th><th>mta_tax</th><th>tip_amount</th><th>tolls_amount</th><th>improvement_surcharge</th><th>total_amount</th><th>congestion_surcharge</th><th>airport_fee</th><th>date</th><th>Revenue</th></tr></thead><tbody><tr><td>1</td><td>2018-01-01T00:21:05.000+0000</td><td>2018-01-01T00:24:23.000+0000</td><td>1</td><td>0.5</td><td>1</td><td>N</td><td>41</td><td>24</td><td>2</td><td>4.5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>5.8</td><td>null</td><td>null</td><td>2018-01-01</td><td>11.6</td></tr><tr><td>1</td><td>2018-01-01T00:44:55.000+0000</td><td>2018-01-01T01:03:05.000+0000</td><td>1</td><td>2.7</td><td>1</td><td>N</td><td>239</td><td>140</td><td>2</td><td>14.0</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>15.3</td><td>null</td><td>null</td><td>2018-01-01</td><td>30.6</td></tr><tr><td>1</td><td>2018-01-01T00:08:26.000+0000</td><td>2018-01-01T00:14:21.000+0000</td><td>2</td><td>0.8</td><td>1</td><td>N</td><td>262</td><td>141</td><td>1</td><td>6.0</td><td>0.5</td><td>0.5</td><td>1.0</td><td>0.0</td><td>0.3</td><td>8.3</td><td>null</td><td>null</td><td>2018-01-01</td><td>16.6</td></tr><tr><td>1</td><td>2018-01-01T00:20:22.000+0000</td><td>2018-01-01T00:52:51.000+0000</td><td>1</td><td>10.2</td><td>1</td><td>N</td><td>140</td><td>257</td><td>2</td><td>33.5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>34.8</td><td>null</td><td>null</td><td>2018-01-01</td><td>69.6</td></tr><tr><td>1</td><td>2018-01-01T00:09:18.000+0000</td><td>2018-01-01T00:27:06.000+0000</td><td>2</td><td>2.5</td><td>1</td><td>N</td><td>246</td><td>239</td><td>1</td><td>12.5</td><td>0.5</td><td>0.5</td><td>2.75</td><td>0.0</td><td>0.3</td><td>16.55</td><td>null</td><td>null</td><td>2018-01-01</td><td>33.1</td></tr></tbody></table></div>

# %% [markdown]
# ##### 
5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>6.8</td><td>null</td><td>null</td><td>2018-01-01</td><td>13.6</td></tr></tbody></table></div>

# %% [markdown]
# ##### 3. Realtime Average fare/total earning amount earned by 2 vendors

# %%
query_3_df=df.groupby("VendorID").sum('fare_amount')
display(query_3_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>sum(fare_amount)</th></tr></thead><tbody><tr><td>1</td><td>4.599966776999971E7</td></tr><tr><td>2</td><td>6.126991590999834E7</td></tr></tbody></table></div>

# %%
df \
    .where("VendorID is not null")\
    .groupBy("VendorID")\
    .agg(sum("fare_amount"))\
    .select("VendorID",col("sum(fare_amount)").alias("Total_of_Fare_Amount"))\
    .orderBy("VendorID")\
    .show()
# Out:
# +--------+--------------------+
# |VendorID|Total_of_Fare_Amount|
# +--------+--------------------+
# |       1| 4.599966776999971E7|
# |       2| 6.126991590999834E7|
# +--------+--------------------+

# %% [markdown]
# ##### 4. Moving Count of payments made by each payment mode

# %%
query_4_df=df.groupby("payment_type").agg(count("passenger_count"))
display(query_4_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_type</th><th>count(passenger_count)</th></tr></thead><tbody><tr><td>1</td><td>6106416</td></tr><tr><td>3</td><td>43204</td></tr><tr><td>2</td><td>2599215</td></tr><tr><td>4</td><td>11852</td></tr></tbody></table></div>

# %% [markdown]
# ###### 5. Highest two gaining vendor's on a particular date with no of passenger and total distance by cab

# %%
#df = df.column(to_date("tpep_pickup_datetime"))
df = df.withColumn("date",to_date("tpep_pickup_datetime"))
query_5_df = (df.groupBy("VendorID","date")
         .agg(sum("passenger_count").alias("total_passenger"),
              sum("trip_distance").alias("total_distance"),
              sum("Revenue").alias("total_revenue")))
display(query_5_df.sort(desc("total_revenue")).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>date</th><th>total_passenger</th><th>total_distance</th><th>total_revenue</th></tr></thead><tbody><tr><td>2</td><td>2018-01-25</td><td>351475</td><td>518394.0400000009</td><td>5966751.749995339</td></tr><tr><td>2</td><td>2018-01-26</td><td>354497</td><td>513454.3299999982</td><td>5927691.89999487</td></tr><tr><td>2</td><td>2018-01-18</td><td>349639</td><td>508573.5399999963</td><td>5843828.609995884</td></tr><tr><td>2</td><td>2018-01-12</td><td>335281</td><td>503578.94999999343</td><td>5768679.019995909</td></tr><tr><td>2</td><td>2018-01-19</td><td>341985</td><td>500606.6799999969</td><td>5708885.429996097</td></tr><tr><td>2</td><td>2018-01-11</td><td>322541</td><td>500037.5800000092</td><td>5662251.419996866</td></tr><tr><td>2</td><td>2018-01-24</td><td>330770</td><td>483133.2800000022</td><td>5526454.289997513</td></tr><tr><td>2</td><td>2018-01-31</td><td>333799</td><td>477673.21999999107</td><td>5518215.479997609</td></tr><tr><td>2</td><td>2018-01-16</td><td>314680</td><td>484168.6700000066</td><td>5419015.129997958</td></tr><tr><td>2</td><td>2018-01-13</td><td>349181</td><td>500069.0500000009</td><td>5365273.399997983</td></tr></tbody></table></div>

# %% [markdown]
# d
# ##### 6. Most no of passenger between a route of two location

# %%
query_6_df=(df.groupby("PULocationID","DOLocationID")
     .agg(sum("passenger_count")))
display(query_6_df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PULocationID</th><th>DOLocationID</th><th>sum(passenger_count)</th></tr></thead><tbody><tr><td>79</td><td>116</td><td>580</td></tr><tr><td>246</td><td>249</td><td>5073</td></tr><tr><td>234</td><td>144</td><td>7047</td></tr><tr><td>161</td><td>193</td><td>100</td></tr><tr><td>231</td><td>261</td><td>5812</td></tr><tr><td>143</td><td>211</td><td>260</td></tr><tr><td>90</td><td>231</td><td>6447</td></tr><tr><td>142</td><td>144</td><td>971</td></tr><tr><td>90</td><td>142</td><td>2835</td></tr><tr><td>249</td><td>225</td><td>400</td></tr></tbody></table></div>

# %% [markdown]
# ###### 7. Get top pickup locations with most passengers in last 5/10 seconds.
